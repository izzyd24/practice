# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statistics
# Load in csv
df = pd.read_csv("matches.csv")
df.head()
# Out:
#    loser_age  loser_id             loser_name  loser_rank  winner_age  \
# 0  17.859001    200002          Mirjana Lucic          49   19.296372
# 1  27.118412    200004        Kerry Anne Guse         133   17.629021
# 2  31.378508    200005  Jolene Watanabe Giltz         118   26.458590
# 3  22.006845    200007         Silvija Talaja          23   18.970568
# 4  24.821355    200010            Rita Grande          60   22.650240
#
#    winner_id          winner_name  winner_rank
# 0     200001       Martina Hingis            1
# 1     200003        Justine Henin           63
# 2     200006     Karina Habsudova           53
# 3     200008         Alicia Molik          116
# 4     200009  Tamarine Tanasugarn           72

# %%
# create table, find serna wins 
dfnew = df[df["winner_name"] == "Serena Williams"]
dfnew.count()
# Out:
# loser_age      37
# loser_id       37
# loser_name     37
# loser_rank     37
# winner_age     37
# winner_id      37
# winner_name    37
# winner_rank    37
# dtype: int64

# %%
# players
df = pd.read_csv("players.csv")
df.head()
# Out:
#    player_id  first_name       last_name hand country_code
# 0     200001     Martina          Hingis    R          SUI
# 1     200002     Mirjana           Lucic    R          CRO
# 2     200003     Justine           Henin    R          BEL
# 3     200004  Kerry Anne            Guse    R          AUS
# 4     200005      Jolene  Watanabe Giltz    R          USA

# %%
# write a query that returns the count of players for each dominant hand group (i.e. right, left)
dfrighty = df[df["hand"] == "R"]
dfrighty.count()
# Out:
# player_id       5023
# first_name      5023
# last_name       5023
# hand            5023
# country_code    5023
# dtype: int64

# %%
# write a query that returns the count of players for each dominant hand group (i.e. right, left)
dfrighty = df[df["hand"] == "L"]
dfrighty.count()
# Out:
# player_id       487
# first_name      487
# last_name       487
# hand            487
# country_code    487
# dtype: int64

# %%
# count number of match winners
df
# shows 19,234 total wins from 487 lefty, 5000+ righty
# Out:
#        player_id  first_name       last_name hand country_code
# 0         200001     Martina          Hingis    R          SUI
# 1         200002     Mirjana           Lucic    R          CRO
# 2         200003     Justine           Henin    R          BEL
# 3         200004  Kerry Anne            Guse    R          AUS
# 4         200005      Jolene  Watanabe Giltz    R          USA
# ...          ...         ...             ...  ...          ...
# 19229     220668       Jimin            Kwon    U          KOR
# 19230     220669      Ye Jin             Kim    U          KOR
# 19231     220670        Anna           Speri    U          ITA
# 19232     220671    Katerina         Krizova    R          CZE
# 19233     220672      Milana     Zhabrailova    U          RUS
#
# [19234 rows x 5 columns]

# %%
df_cta_list_lstops = pd.read_csv("CTA_list_of_L_stops.csv")
df_cta_list_lstops.head()
# Out:
#    STOP_ID DIRECTION_ID                        STOP_NAME  \
# 0    30162            W         18th (54th/Cermak-bound)
# 1    30161            E                18th (Loop-bound)
# 2    30022            N         35th/Archer (Loop-bound)
# 3    30023            S       35th/Archer (Midway-bound)
# 4    30214            S  35-Bronzeville-IIT (63rd-bound)
#
#            STATION_NAME           STATION_DESCRIPTIVE_NAME  MAP_ID   ADA  \
# 0                  18th                   18th (Pink Line)   40830  True
# 1                  18th                   18th (Pink Line)   40830  True
# 2           35th/Archer          35th/Archer (Orange Line)   40120  True
# 3           35th/Archer          35th/Archer (Orange Line)   40120  True
# 4  35th-Bronzeville-IIT  35th-Bronzeville-IIT (Green Line)   41120  True
#
#      RED   BLUE      G    BRN      P   Pexp      Y    Pnk      O  \
# 0  False  False  False  False  False  False  False   True  False
# ...

# %%
df_cta_daily = pd.read_csv("CTA_ridership_daily_totals.csv")
df_cta_daily.head()
# Out:
#    station_id         stationname      date daytype  rides
# 0       40050               Davis  1/1/2016       U   1415
# 1       41200              Argyle  1/1/2016       U   1741
# 2       40970  Cicero-Forest Park  1/1/2016       U    722
# 3       40490     Grand/Milwaukee  1/1/2016       U   1700
# 4       41130      Halsted-Orange  1/1/2016       U    764

# %%
# merge the two previous dfs
combined_data = pd.merge(df_cta_list_lstops, df_cta_daily, on= "MAP_ID", how = "inner")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_68052/593273335.py in <module>
#       1 # merge the two previous dfs
# ----> 2 combined_data = pd.merge(df_cta_list_lstops, df_cta_daily, on= "MAP_ID", how = "inner")
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     117         copy=copy,
#     118         indicator=indicator,
# --> 119         validate=validate,
#     120     )
#     121     return op.get_result()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     697             self.right_join_keys,
# ...
